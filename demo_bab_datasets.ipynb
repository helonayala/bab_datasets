# %% [markdown]
# # bab_datasets demo
#
# This notebook shows how to load and preprocess datasets using `bab_datasets`.

# %%
# If you're in the repo, install editable once:
# !pip install -e .

import bab_datasets as nod

# %%
# List available experiments
print(nod.list_experiments())

# %%
# Load with preprocessing and plots
# If you haven't trimmed yet, set plot=True and pick end_idx manually after the zoom

exp = "multisine_05"
train_val = nod.load_experiment(exp, preprocess=True, plot=True, end_idx=None, resample_factor=50, zoom_last_n=2000)

u, y = train_val
print(train_val)

# %%
# Example slice
print(train_val[:100])
